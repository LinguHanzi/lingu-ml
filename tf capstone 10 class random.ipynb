# %%
# !pip install keras_preprocessing
# Out:
# Collecting keras_preprocessing
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras_preprocessing) (1.25.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from keras_preprocessing) (1.16.0)
# Installing collected packages: keras_preprocessing
# Successfully installed keras_preprocessing-1.1.2

# %%
import urllib.request
import zipfile
import tensorflow as tf
import os
from keras_preprocessing.image import ImageDataGenerator



# data_url = 'https://github.com/AurelLighT/bangkit-data/blob/main/data.zip'
# urllib.request.urlretrieve(data_url, 'data.zip')
local_file = 'data.zip'
zip_ref = zipfile.ZipFile(local_file, 'r')
zip_ref.extractall('data/')
zip_ref.close()

TRAINING_DIR = "data/train/"
VALID_DIR = "data/valid/"
TEST_DIR = "data/test/"
training_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=10,
    shear_range=0.,
    zoom_range=0.15,
    fill_mode='nearest')
valid_datagen = ImageDataGenerator(
    rescale=1./255)
test_datagen = ImageDataGenerator(
    rescale=1./255)
# YOUR IMAGE SIZE SHOULD BE 150x150
# Make sure you used "categorical"
train_generator = training_datagen.flow_from_directory(
    TRAINING_DIR,
    class_mode='categorical',
    batch_size=64,
    target_size=(150, 150))
valid_generator = valid_datagen.flow_from_directory(
    VALID_DIR,
    class_mode='categorical',
    batch_size=64,
    target_size=(150, 150))
test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    class_mode='categorical',
    batch_size=64,
    target_size=(150, 150)
)
model=tf.keras.models.Sequential([
# YOUR CODE HERE, end with 3 Neuron Dense, activated by softmax
  tf.keras.layers.Conv2D(16, (3,3), input_shape=(150,150,3)),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(32, (3,3)),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(64, (3,3)),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128),
  tf.keras.layers.Dense(10, activation='softmax')
])
model.compile(
    optimizer = 'adam',
    loss = 'categorical_crossentropy',
    metrics = 'accuracy'
)
model.fit(train_generator, epochs=100, validation_data=valid_generator)
# Out:
# Found 400 images belonging to 10 classes.
# Found 50 images belonging to 10 classes.
# Found 60 images belonging to 10 classes.
# Epoch 1/100
# 7/7 [==============================] - 9s 483ms/step - loss: 15.2441 - accuracy: 0.0850 - val_loss: 5.7627 - val_accuracy: 0.2000
# Epoch 2/100
# 7/7 [==============================] - 2s 294ms/step - loss: 5.4700 - accuracy: 0.2325 - val_loss: 2.9090 - val_accuracy: 0.3400
# Epoch 3/100
# 7/7 [==============================] - 2s 314ms/step - loss: 2.8447 - accuracy: 0.2775 - val_loss: 1.7534 - val_accuracy: 0.6000
# Epoch 4/100
# 7/7 [==============================] - 2s 304ms/step - loss: 1.5981 - accuracy: 0.5200 - val_loss: 0.9166 - val_accuracy: 0.7600
# Epoch 5/100
# 7/7 [==============================] - 2s 296ms/step - loss: 1.1365 - accuracy: 0.6400 - val_loss: 1.0088 - val_accuracy: 0.6200
# Epoch 6/100
# 7/7 [==============================] - 3s 500ms/step - loss: 0.8992 - accuracy: 0.7000 - val_loss: 0.8224 - val_accuracy: 0.7000
# Epoch 7/100
# 7/7 [==============================] - 3s 371ms/step - loss: 0.8313 - accuracy: 0.7450 - val_loss: 0.6765 - val_accuracy: 0.7000
# Epoch 8/100
# 7/7 [==============================] - 2s 299ms/step - loss: 0.6615 - accuracy: 0.7975 - val_loss: 0.6587 - val_accuracy: 0.8200
# Epoch 9/100
# 7/7 [==============================] - 2s 342ms/step - loss: 0.5091 - accuracy: 0.8675 - val_loss: 0.5051 - val_accuracy: 0.8800
# Epoch 10/100
# 7/7 [==============================] - 4s 612ms/step - loss: 0.4805 - accuracy: 0.8675 - val_loss: 0.5162 - val_accuracy: 0.8600
# Epoch 11/100
# 7/7 [==============================] - 3s 402ms/step - loss: 0.4351 - accuracy: 0.8925 - val_loss: 0.4194 - val_accuracy: 0.8600
# Epoch 12/100
# 7/7 [==============================] - 2s 292ms/step - loss: 0.3946 - accuracy: 0.8725 - val_loss: 0.5744 - val_accuracy: 0.8000
# Epoch 13/100
# 7/7 [==============================] - 2s 301ms/step - loss: 0.3616 - accuracy: 0.9025 - val_loss: 0.4046 - val_accuracy: 0.8600
# Epoch 14/100
# 7/7 [==============================] - 2s 301ms/step - loss: 0.3264 - accuracy: 0.9150 - val_loss: 0.3696 - val_accuracy: 0.8800
# Epoch 15/100
# 7/7 [==============================] - 2s 297ms/step - loss: 0.3006 - accuracy: 0.9225 - val_loss: 0.4807 - val_accuracy: 0.8600
# Epoch 16/100
# 7/7 [==============================] - 4s 507ms/step - loss: 0.2968 - accuracy: 0.9175 - val_loss: 0.3910 - val_accuracy: 0.8800
# Epoch 17/100
# 7/7 [==============================] - 2s 299ms/step - loss: 0.2677 - accuracy: 0.9225 - val_loss: 0.3287 - val_accuracy: 0.9000
# Epoch 18/100
# 7/7 [==============================] - 2s 299ms/step - loss: 0.2221 - accuracy: 0.9450 - val_loss: 0.4618 - val_accuracy: 0.8600
# Epoch 19/100
# 7/7 [==============================] - 2s 295ms/step - loss: 0.2240 - accuracy: 0.9350 - val_loss: 0.3392 - val_accuracy: 0.9000
# Epoch 20/100
# 7/7 [==============================] - 2s 292ms/step - loss: 0.1955 - accuracy: 0.9475 - val_loss: 0.3917 - val_accuracy: 0.8800
# Epoch 21/100
# 7/7 [==============================] - 3s 422ms/step - loss: 0.1907 - accuracy: 0.9425 - val_loss: 0.2922 - val_accuracy: 0.9000
# Epoch 22/100
# 7/7 [==============================] - 3s 367ms/step - loss: 0.1698 - accuracy: 0.9525 - val_loss: 0.3610 - val_accuracy: 0.8800
# Epoch 23/100
# 7/7 [==============================] - 2s 371ms/step - loss: 0.2155 - accuracy: 0.9425 - val_loss: 0.2709 - val_accuracy: 0.9000
# Epoch 24/100
# 7/7 [==============================] - 2s 343ms/step - loss: 0.2149 - accuracy: 0.9300 - val_loss: 0.4021 - val_accuracy: 0.8600
# Epoch 25/100
# 7/7 [==============================] - 2s 294ms/step - loss: 0.1874 - accuracy: 0.9550 - val_loss: 0.3117 - val_accuracy: 0.8800
# Epoch 26/100
# 7/7 [==============================] - 2s 344ms/step - loss: 0.1610 - accuracy: 0.9575 - val_loss: 0.3801 - val_accuracy: 0.8800
# Epoch 27/100
# 7/7 [==============================] - 3s 429ms/step - loss: 0.1461 - accuracy: 0.9650 - val_loss: 0.2578 - val_accuracy: 0.9200
# Epoch 28/100
# 7/7 [==============================] - 2s 296ms/step - loss: 0.1385 - accuracy: 0.9650 - val_loss: 0.4888 - val_accuracy: 0.8600
# Epoch 29/100
# 7/7 [==============================] - 2s 297ms/step - loss: 0.1486 - accuracy: 0.9500 - val_loss: 0.2652 - val_accuracy: 0.9000
# Epoch 30/100
# 7/7 [==============================] - 2s 299ms/step - loss: 0.1405 - accuracy: 0.9675 - val_loss: 0.2667 - val_accuracy: 0.9400
# Epoch 31/100
# 7/7 [==============================] - 2s 310ms/step - loss: 0.1298 - accuracy: 0.9700 - val_loss: 0.4499 - val_accuracy: 0.8600
# Epoch 32/100
# 7/7 [==============================] - 4s 491ms/step - loss: 0.1195 - accuracy: 0.9650 - val_loss: 0.2879 - val_accuracy: 0.9000
# Epoch 33/100
# 7/7 [==============================] - 2s 303ms/step - loss: 0.0927 - accuracy: 0.9775 - val_loss: 0.2629 - val_accuracy: 0.9200
# Epoch 34/100
# 7/7 [==============================] - 2s 304ms/step - loss: 0.0872 - accuracy: 0.9825 - val_loss: 0.3324 - val_accuracy: 0.9000
# Epoch 35/100
# 7/7 [==============================] - 2s 304ms/step - loss: 0.1051 - accuracy: 0.9700 - val_loss: 0.2877 - val_accuracy: 0.8800
# Epoch 36/100
# 7/7 [==============================] - 2s 295ms/step - loss: 0.0877 - accuracy: 0.9725 - val_loss: 0.2317 - val_accuracy: 0.9000
# Epoch 37/100
# 7/7 [==============================] - 4s 500ms/step - loss: 0.1049 - accuracy: 0.9675 - val_loss: 0.3540 - val_accuracy: 0.9000
# Epoch 38/100
# 7/7 [==============================] - 2s 335ms/step - loss: 0.1225 - accuracy: 0.9525 - val_loss: 0.3320 - val_accuracy: 0.8800
# Epoch 39/100
# 7/7 [==============================] - 2s 292ms/step - loss: 0.0924 - accuracy: 0.9675 - val_loss: 0.2697 - val_accuracy: 0.9200
# Epoch 40/100
# 7/7 [==============================] - 2s 295ms/step - loss: 0.0993 - accuracy: 0.9675 - val_loss: 0.4592 - val_accuracy: 0.8600
# Epoch 41/100
# 7/7 [==============================] - 3s 410ms/step - loss: 0.1030 - accuracy: 0.9600 - val_loss: 0.2747 - val_accuracy: 0.9000
# Epoch 42/100
# 7/7 [==============================] - 3s 399ms/step - loss: 0.1081 - accuracy: 0.9675 - val_loss: 0.3050 - val_accuracy: 0.9000
# Epoch 43/100
# 7/7 [==============================] - 2s 297ms/step - loss: 0.0845 - accuracy: 0.9725 - val_loss: 0.3476 - val_accuracy: 0.8800
# Epoch 44/100
# 7/7 [==============================] - 2s 347ms/step - loss: 0.0684 - accuracy: 0.9825 - val_loss: 0.2575 - val_accuracy: 0.8800
# Epoch 45/100
# 7/7 [==============================] - 2s 292ms/step - loss: 0.0587 - accuracy: 0.9925 - val_loss: 0.2733 - val_accuracy: 0.9000
# Epoch 46/100
# 7/7 [==============================] - 4s 455ms/step - loss: 0.0939 - accuracy: 0.9700 - val_loss: 0.2668 - val_accuracy: 0.9000
# Epoch 47/100
# 7/7 [==============================] - 3s 520ms/step - loss: 0.0572 - accuracy: 0.9825 - val_loss: 0.2704 - val_accuracy: 0.9000
# Epoch 48/100
# 7/7 [==============================] - 2s 297ms/step - loss: 0.0467 - accuracy: 0.9850 - val_loss: 0.2851 - val_accuracy: 0.8800
# Epoch 49/100
# 7/7 [==============================] - 2s 344ms/step - loss: 0.0587 - accuracy: 0.9800 - val_loss: 0.2536 - val_accuracy: 0.9000
# Epoch 50/100
# 7/7 [==============================] - 3s 425ms/step - loss: 0.0407 - accuracy: 0.9900 - val_loss: 0.2494 - val_accuracy: 0.9400
# Epoch 51/100
# 7/7 [==============================] - 2s 308ms/step - loss: 0.0502 - accuracy: 0.9925 - val_loss: 0.2880 - val_accuracy: 0.9200
# Epoch 52/100
# 7/7 [==============================] - 2s 296ms/step - loss: 0.0589 - accuracy: 0.9825 - val_loss: 0.2811 - val_accuracy: 0.9000
# Epoch 53/100
# 7/7 [==============================] - 2s 294ms/step - loss: 0.0521 - accuracy: 0.9900 - val_loss: 0.3186 - val_accuracy: 0.8800
# Epoch 54/100
# 7/7 [==============================] - 2s 298ms/step - loss: 0.0602 - accuracy: 0.9875 - val_loss: 0.2900 - val_accuracy: 0.9200
# Epoch 55/100
# 7/7 [==============================] - 4s 569ms/step - loss: 0.0375 - accuracy: 0.9925 - val_loss: 0.2986 - val_accuracy: 0.9200
# Epoch 56/100
# 7/7 [==============================] - 2s 294ms/step - loss: 0.0540 - accuracy: 0.9900 - val_loss: 0.2557 - val_accuracy: 0.9000
# Epoch 57/100
# 7/7 [==============================] - 2s 336ms/step - loss: 0.0379 - accuracy: 0.9875 - val_loss: 0.2309 - val_accuracy: 0.9400
# Epoch 58/100
# 7/7 [==============================] - 2s 331ms/step - loss: 0.0293 - accuracy: 0.9950 - val_loss: 0.2151 - val_accuracy: 0.9400
# Epoch 59/100
# 7/7 [==============================] - 2s 309ms/step - loss: 0.0347 - accuracy: 0.9900 - val_loss: 0.2793 - val_accuracy: 0.9200
# Epoch 60/100
# 7/7 [==============================] - 4s 531ms/step - loss: 0.0255 - accuracy: 1.0000 - val_loss: 0.2955 - val_accuracy: 0.9200
# Epoch 61/100
# 7/7 [==============================] - 2s 297ms/step - loss: 0.0441 - accuracy: 0.9900 - val_loss: 0.2900 - val_accuracy: 0.9200
# Epoch 62/100
# 7/7 [==============================] - 2s 296ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.2451 - val_accuracy: 0.9200
# Epoch 63/100
# 7/7 [==============================] - 4s 499ms/step - loss: 0.0317 - accuracy: 0.9925 - val_loss: 0.2600 - val_accuracy: 0.9000
# Epoch 64/100
# 7/7 [==============================] - 3s 443ms/step - loss: 0.0368 - accuracy: 0.9900 - val_loss: 0.2276 - val_accuracy: 0.9200
# Epoch 65/100
# 7/7 [==============================] - 2s 397ms/step - loss: 0.0321 - accuracy: 0.9950 - val_loss: 0.2238 - val_accuracy: 0.9200
# Epoch 66/100
# 7/7 [==============================] - 2s 291ms/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.2705 - val_accuracy: 0.9200
# Epoch 67/100
# 7/7 [==============================] - 2s 329ms/step - loss: 0.0185 - accuracy: 0.9975 - val_loss: 0.2752 - val_accuracy: 0.9400
# Epoch 68/100
# 7/7 [==============================] - 3s 469ms/step - loss: 0.0299 - accuracy: 0.9925 - val_loss: 0.3172 - val_accuracy: 0.9200
# Epoch 69/100
# 7/7 [==============================] - 2s 322ms/step - loss: 0.0195 - accuracy: 1.0000 - val_loss: 0.3038 - val_accuracy: 0.9200
# Epoch 70/100
# 7/7 [==============================] - 2s 330ms/step - loss: 0.0233 - accuracy: 0.9975 - val_loss: 0.2386 - val_accuracy: 0.9200
# Epoch 71/100
# 7/7 [==============================] - 2s 308ms/step - loss: 0.0229 - accuracy: 0.9925 - val_loss: 0.2167 - val_accuracy: 0.9200
# Epoch 72/100
# 7/7 [==============================] - 2s 297ms/step - loss: 0.0655 - accuracy: 0.9825 - val_loss: 0.3053 - val_accuracy: 0.8800
# Epoch 73/100
# 7/7 [==============================] - 4s 604ms/step - loss: 0.0376 - accuracy: 0.9925 - val_loss: 0.3364 - val_accuracy: 0.9000
# Epoch 74/100
# 7/7 [==============================] - 2s 292ms/step - loss: 0.0226 - accuracy: 0.9975 - val_loss: 0.3745 - val_accuracy: 0.8600
# Epoch 75/100
# 7/7 [==============================] - 2s 295ms/step - loss: 0.0291 - accuracy: 0.9950 - val_loss: 0.2338 - val_accuracy: 0.9400
# Epoch 76/100
# 7/7 [==============================] - 2s 297ms/step - loss: 0.0214 - accuracy: 0.9975 - val_loss: 0.2907 - val_accuracy: 0.9000
# Epoch 77/100
# 7/7 [==============================] - 2s 288ms/step - loss: 0.0369 - accuracy: 0.9950 - val_loss: 0.2667 - val_accuracy: 0.9200
# Epoch 78/100
# 7/7 [==============================] - 3s 447ms/step - loss: 0.0177 - accuracy: 0.9975 - val_loss: 0.3396 - val_accuracy: 0.9000
# Epoch 79/100
# 7/7 [==============================] - 3s 334ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.3058 - val_accuracy: 0.9200
# Epoch 80/100
# 7/7 [==============================] - 2s 291ms/step - loss: 0.0219 - accuracy: 0.9925 - val_loss: 0.3338 - val_accuracy: 0.9000
# Epoch 81/100
# 7/7 [==============================] - 2s 293ms/step - loss: 0.0168 - accuracy: 0.9975 - val_loss: 0.2707 - val_accuracy: 0.9200
# Epoch 82/100
# 7/7 [==============================] - 2s 329ms/step - loss: 0.0126 - accuracy: 0.9975 - val_loss: 0.3066 - val_accuracy: 0.9200
# Epoch 83/100
# 7/7 [==============================] - 3s 431ms/step - loss: 0.0237 - accuracy: 0.9975 - val_loss: 0.3992 - val_accuracy: 0.9200
# Epoch 84/100
# 7/7 [==============================] - 2s 294ms/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.2704 - val_accuracy: 0.9200
# Epoch 85/100
# 7/7 [==============================] - 2s 291ms/step - loss: 0.0214 - accuracy: 0.9950 - val_loss: 0.3116 - val_accuracy: 0.9200
# Epoch 86/100
# 7/7 [==============================] - 2s 293ms/step - loss: 0.0200 - accuracy: 0.9925 - val_loss: 0.2760 - val_accuracy: 0.9200
# Epoch 87/100
# 7/7 [==============================] - 3s 469ms/step - loss: 0.0160 - accuracy: 0.9950 - val_loss: 0.2530 - val_accuracy: 0.9200
# Epoch 88/100
# 7/7 [==============================] - 3s 472ms/step - loss: 0.0167 - accuracy: 0.9975 - val_loss: 0.2471 - val_accuracy: 0.9200
# Epoch 89/100
# 7/7 [==============================] - 2s 342ms/step - loss: 0.0158 - accuracy: 0.9950 - val_loss: 0.2774 - val_accuracy: 0.9200
# Epoch 90/100
# 7/7 [==============================] - 2s 341ms/step - loss: 0.0170 - accuracy: 0.9975 - val_loss: 0.2842 - val_accuracy: 0.9200
# Epoch 91/100
# 7/7 [==============================] - 2s 296ms/step - loss: 0.0131 - accuracy: 0.9975 - val_loss: 0.3103 - val_accuracy: 0.9200
# Epoch 92/100
# 7/7 [==============================] - 2s 296ms/step - loss: 0.0219 - accuracy: 0.9950 - val_loss: 0.2838 - val_accuracy: 0.9200
# Epoch 93/100
# 7/7 [==============================] - 3s 458ms/step - loss: 0.0194 - accuracy: 0.9975 - val_loss: 0.2568 - val_accuracy: 0.9200
# Epoch 94/100
# 7/7 [==============================] - 2s 303ms/step - loss: 0.0168 - accuracy: 0.9950 - val_loss: 0.2923 - val_accuracy: 0.9000
# Epoch 95/100
# 7/7 [==============================] - 2s 303ms/step - loss: 0.0170 - accuracy: 0.9975 - val_loss: 0.2851 - val_accuracy: 0.9200
# Epoch 96/100
# 7/7 [==============================] - 2s 294ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.3902 - val_accuracy: 0.9000
# Epoch 97/100
# 7/7 [==============================] - 2s 301ms/step - loss: 0.0211 - accuracy: 0.9875 - val_loss: 0.3209 - val_accuracy: 0.9200
# Epoch 98/100
# 7/7 [==============================] - 4s 517ms/step - loss: 0.0248 - accuracy: 0.9925 - val_loss: 0.3730 - val_accuracy: 0.8800
# Epoch 99/100
# 7/7 [==============================] - 2s 301ms/step - loss: 0.0318 - accuracy: 0.9900 - val_loss: 0.4036 - val_accuracy: 0.9200
# Epoch 100/100
# 7/7 [==============================] - 2s 293ms/step - loss: 0.0160 - accuracy: 0.9975 - val_loss: 0.2085 - val_accuracy: 0.9200

# %%
results = model.evaluate(test_generator)
print("test loss, test acc:", results)
# Out:
# 1/1 [==============================] - 1s 893ms/step - loss: 0.2092 - accuracy: 0.9500
# test loss, test acc: [0.20923098921775818, 0.949999988079071]

# %%
model.save("yey.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
